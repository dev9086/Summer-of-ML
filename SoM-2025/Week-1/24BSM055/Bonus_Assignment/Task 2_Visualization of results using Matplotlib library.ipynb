# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('world-happiness-report-2021.csv')

# %% [markdown]
# ### 1. Display the data of top 5 east asian countries based on 'Generosity'

# %%
east_asian = df1[df1['Regional indicator'] == 'East Asia']
top5 = east_asian.sort_values(by='Generosity', ascending=False).head(5)
top5
# Out:
#                  Country name Regional indicator  Ladder score  \
# 69                   Mongolia          East Asia         5.677
# 76  Hong Kong S.A.R. of China          East Asia         5.477
# 23   Taiwan Province of China          East Asia         6.584
# 61                South Korea          East Asia         5.845
# 83                      China          East Asia         5.339
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 69                           0.042         5.760         5.595
# 76                           0.049         5.573         5.380
# 23                           0.038         6.659         6.510
# 61                           0.042         5.928         5.763
# 83                           0.029         5.397         5.281
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 69                  9.400           0.935                   62.500
# 76                 11.000           0.836                   76.820
# ...

# %% [markdown]
# ### 2. Build a plot (line plot) that shows the variation of 'Ladder score' among the above 5 east asian countries (based on generosity)

# %%
plt.plot(top5['Country name'], top5['Ladder score'])
plt.xlabel("Country")
plt.ylabel("Ladder Score")
plt.show()

# %% [markdown]
# ### 3. Create a dataframe object : df_2021 with the following countries: 'China', 'Nepal', 'Bangladesh', 'Pakistan', 'Myanmar', 'India', 'Afghanistan'.Now, build a scatter plot to show the relation these countries vs their 'Logged GDP per capita'

# %%
df_2021 = df1[df1['Country name'].isin(['China', 'Nepal', 'Bangladesh', 'Pakistan', 'Myanmar', 'India', 'Afghanistan'])]
plt.scatter(df_2021['Country name'] , df_2021['Logged GDP per capita'])
plt.xlabel("Country")
plt.ylabel("Logged GDP per Capita")
plt.show()
