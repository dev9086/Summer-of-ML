# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv('W1_Pokemon.csv')

# %%
df.shape
# Out:
# (800, 13)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.drop(columns=['#'], inplace=True)

# %%
# df.set_index('Name', inplace=True)

# %%
pd.set_option('display.max_rows', None)

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df['Type']=df['Type 1'] +'+'+ df['Type 2']
#df['Type'].drop()

# %%
filtered=df[df['Type']=="Psychic+Flying"].shape[0]
filtered
# Out:
# 6

# %%
df.loc[df["Name"].str.contains("Mega")]
# Out:
#                           Name    Type 1    Type 2  Total   HP  Attack  \
# 3        VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7    CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8    CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19       BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23         PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71       AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87         SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137          PinsirMega Pinsir       Bug    Flying    600   65     155
# 141      GyaradosMega Gyarados     Water      Dark    640   95     155
# ...

# %%
df["Sp. Def"].std()
# Out:
# np.float64(27.82891579711746)

# %%
per=(df["Legendary"] == True).mean() * 100
print(f"{per:.3f}")
# Out:
# 8.125

# %%
max_def=df[df['Defense']==df['Defense'].max()]
max_def
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 224  SteelixMega Steelix  Steel  Ground    610  75     125      230       55
# 230              Shuckle    Bug    Rock    505  20      10      230       10
# 333    AggronMega Aggron  Steel     NaN    630  70     140      230       60
#
#      Sp. Def  Speed  Generation  Legendary          Type
# 224       95     30           2      False  Steel+Ground
# 230      230      5           2      False      Bug+Rock
# 333       80     50           3      False           NaN

# %%
poison=df[(df['Type 1'] =="Poison") | (df['Type 2']=="Poison")]
poison
poison[poison["Attack"] == poison["Attack"].max()]
# Out:
#                      Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 19  BeedrillMega Beedrill    Bug  Poison    495  65     150       40       15
#
#     Sp. Def  Speed  Generation  Legendary        Type
# 19       80    145           1      False  Bug+Poison

# %%
sns.boxplot(x=df['Generation'],y=df.Defense,hue=df['Legendary'],hue_order=[True,False],width=0.5,linewidth=1)
sns.set_style('dark')

# %%
sns.pairplot(df)

# %%
req=df[(df['Generation']==4) & ((df['Type 1']=="Ghost") | (df['Type 2']=="Ghost")) & (df['Legendary']==False) ]
sec_fast=req['Speed'].nlargest(2).iloc[-1]
req[req['Speed']==sec_fast]
# Out:
#           Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 477  Mismagius  Ghost    NaN    495  60      60       60      105      105
#
#      Speed  Generation  Legendary Type
# 477    105           4      False  NaN

# %%
df[(df['Legendary'] == False)&(df['Attack']<df[df['Name']=="Charizard"]['Attack'].values[0])&(df['Defense']>df[df['Name']=="Charizard"]['Defense'].values[0])]
# Out:
#                         Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 2                   Venusaur     Grass    Poison    525   80      82       83
# 10                 Wartortle     Water       NaN    405   59      63       80
# 11                 Blastoise     Water       NaN    530   79      83      100
# 23       PidgeotMega Pidgeot    Normal    Flying    579   83      80       80
# 32                 Sandshrew    Ground       NaN    300   50      75       85
# 50                 Vileplume     Grass    Poison    490   75      80       85
# 80                   Geodude      Rock    Ground    300   40      80      100
# 86                   Slowbro     Water   Psychic    490   95      75      110
# 87       SlowbroMega Slowbro     Water   Psychic    590   95      75      180
# 89                  Magneton  Electric     Steel    465   50      60       95
# 94                   Dewgong     Water       Ice    475   90      70       80
# ...

# %% [markdown]
# ## bonus

# %%
df['tot_att']=df['Attack']+df['Sp. Atk']
ta_max=df['tot_att'].max()
df[df['tot_att']==ta_max]
# Out:
#                       Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 426  RayquazaMega Rayquaza   Dragon  Flying    780  105     180      100
# 429     DeoxysAttack Forme  Psychic     NaN    600   50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary           Type  tot_att
# 426      180      100    115           3       True  Dragon+Flying      360
# 429      180       20    150           3       True            NaN      360

# %%
typ=df.groupby("Type 1")["Legendary"].mean().idxmax()
typ
# Out:
# 'Flying'

# %%
a=df[(df['Generation']==6) & (df['Legendary']==True)]
df[(df['Generation']==3)&(df['Legendary']==False)&(df['HP']>(a['HP'].min()))]
# Out:
#                         Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 274                 Sceptile     Grass       NaN    530   70      85       65
# 275    SceptileMega Sceptile     Grass    Dragon    630   70     110       75
# 277                Combusken      Fire  Fighting    405   60      85       60
# 278                 Blaziken      Fire  Fighting    530   80     120       70
# 279    BlazikenMega Blaziken      Fire  Fighting    630   80     160       80
# 281                Marshtomp     Water    Ground    405   70      85       70
# 282                 Swampert     Water    Ground    535  100     110       90
# 283    SwampertMega Swampert     Water    Ground    635  100     150      110
# 285                Mightyena      Dark       NaN    420   70      90       70
# 287                  Linoone    Normal       NaN    420   78      70       61
# 290                Beautifly       Bug    Flying    395   60      70       50
# ...

# %%
b=df['Speed'].nsmallest(3).iloc[-1]
df[df['Speed']==b]
# Out:
#           Name  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 359   Trapinch  Ground    NaN    290  45     100       45       45       45
# 486     Bonsly    Rock    NaN    290  50      80       95       10       45
# 658  Ferroseed   Grass  Steel    305  44      50       91       24       86
#
#      Speed  Generation  Legendary         Type  tot_att
# 359     10           3      False          NaN      145
# 486     10           4      False          NaN       90
# 658     10           5      False  Grass+Steel       74

# %%
df.groupby("Type 1")["HP"].mean().idxmax()
# Out:
# 'Dragon'
